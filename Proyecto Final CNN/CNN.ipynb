# %%
import cv2

# %% [markdown]
# # Convolutional Neural Networks

# %% [markdown]
# # Importar Librerías

# %%
import numpy as np
import os
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
import keras
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential,Model
from tensorflow.keras.layers import Input
from keras.layers import Dense, Dropout, Flatten
#from keras.layers import Conv2D, MaxPooling2D
#from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    BatchNormalization, SeparableConv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense, Conv2D
)
from keras.layers import LeakyReLU

# %% [markdown]
# # Cargar set de Imágenes

# %%
dirname = os.path.join(os.getcwd(),'./Flores')
imgpath = dirname + os.sep 
images = []
directories = []
dircount = []
prevRoot=''
cant=0

print("leyendo imagenes de ",imgpath)

for root, dirnames, filenames in os.walk(imgpath):
    for filename in filenames:
        if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
            cant=cant+1
            filepath = os.path.join(root, filename)
            image = plt.imread(filepath)
            if(len(image.shape)==3):
                
                images.append(image)
            b = "Leyendo..." + str(cant)
            print (b, end="\r")
            if prevRoot !=root:
                print(root, cant)
                prevRoot=root
                directories.append(root)
                dircount.append(cant)
                cant=0
dircount.append(cant)

dircount = dircount[1:]
dircount[0]=dircount[0]+1
print('Directorios leidos:',len(directories))
print("Imagenes en cada directorio", dircount)
print('suma Total de imagenes en subdirs:',sum(dircount))
# Out:
# leyendo imagenes de  C:\Users\Tavo\Desktop\IA\P3\CNNModels\./Flores\
# C:\Users\Tavo\Desktop\IA\P3\CNNModels\./Flores\aves 1
# C:\Users\Tavo\Desktop\IA\P3\CNNModels\./Flores\Cempasúchil 3663
# C:\Users\Tavo\Desktop\IA\P3\CNNModels\./Flores\Lavanda 3330
# C:\Users\Tavo\Desktop\IA\P3\CNNModels\./Flores\Lirio_Azteca 1628
# C:\Users\Tavo\Desktop\IA\P3\CNNModels\./Flores\Reina_por_una_Noche 1961
# Directorios leidos: 5
# Imagenes en cada directorio [3664, 3330, 1628, 1961, 1442]
# suma Total de imagenes en subdirs: 12025

# %% [markdown]
# # Creamos las etiquetas

# %%
labels=[]
indice=0
for cantidad in dircount:
    for i in range(cantidad):
        labels.append(indice)
    indice=indice+1
print("Cantidad etiquetas creadas: ",len(labels))
# Out:
# Cantidad etiquetas creadas:  12025

# %%
flores=[]
indice=0
for directorio in directories:
    name = directorio.split(os.sep)
    print(indice , name[len(name)-1])
    flores.append(name[len(name)-1])
    indice=indice+1
# Out:
# 0 aves
# 1 Cempasúchil
# 2 Lavanda
# 3 Lirio_Azteca
# 4 Reina_por_una_Noche

# %%
y = np.array(labels)
X = np.array(images, dtype=np.uint8) #convierto de lista a numpy



# Find the unique numbers from the train labels
classes = np.unique(y)
nClasses = len(classes)
print('Total number of outputs : ', nClasses)
print('Output classes : ', classes)
# Out:
# Total number of outputs :  5
# Output classes :  [0 1 2 3 4]

# %% [markdown]
# # Creamos Sets de Entrenamiento y Test

# %%
train_X,test_X,train_Y,test_Y = train_test_split(X,y,test_size=0.2)
print('Training data shape : ', train_X.shape, train_Y.shape)
print('Testing data shape : ', test_X.shape, test_Y.shape)
# Out:
# Training data shape :  (9620, 32, 32, 3) (9620,)
# Testing data shape :  (2405, 32, 32, 3) (2405,)

# %%
plt.figure(figsize=[5,5])

# Display the first image in training data
plt.subplot(121)
plt.imshow(train_X[0,:,:], cmap='gray')
plt.title("Ground Truth : {}".format(train_Y[0]))

# Display the first image in testing data
plt.subplot(122)
plt.imshow(test_X[0,:,:], cmap='gray')
plt.title("Ground Truth : {}".format(test_Y[0]))
# Out:
# Text(0.5, 1.0, 'Ground Truth : 3')

# %% [markdown]
# # Preprocesamos las imagenes

# %%
train_X = train_X.astype('float32')
test_X = test_X.astype('float32')
train_X = train_X/255.
test_X = test_X/255.
plt.imshow(test_X[0,:,:])

# %% [markdown]
# ## Hacemos el One-hot Encoding para la red

# %%
# Change the labels from categorical to one-hot encoding
train_Y_one_hot = to_categorical(train_Y)
test_Y_one_hot = to_categorical(test_Y)

# Display the change for category label using one-hot encoding
print('Original label:', train_Y[0])
print('After conversion to one-hot:', train_Y_one_hot[0])
# Out:
# Original label: 2
# After conversion to one-hot: [0. 0. 1. 0. 0.]

# %% [markdown]
# # Creamos el Set de Entrenamiento y Validación

# %%
#Mezclar todo y crear los grupos de entrenamiento y testing
train_X,valid_X,train_label,valid_label = train_test_split(train_X, train_Y_one_hot, test_size=0.2, random_state=13)

# %%
print(train_X.shape,valid_X.shape,train_label.shape,valid_label.shape)
# Out:
# (7696, 32, 32, 3) (1924, 32, 32, 3) (7696, 5) (1924, 5)

# %% [markdown]
# # Creamos el modelo de CNN

# %%
#declaramos variables con los parámetros de configuración de la red
INIT_LR = 1e-3 # Valor inicial de learning rate. El valor 1e-3 corresponde con 0.001
epochs = 200 # Cantidad de iteraciones completas al conjunto de imagenes de entrenamiento
batch_size = 32 # cantidad de imágenes que se toman a la vez en memoria

# %%
flower_model = Sequential()
flower_model.add(Conv2D(16, kernel_size=(5, 5),activation='linear',padding='same',input_shape=(32,32,3)))
flower_model.add(LeakyReLU(alpha=0.1))
flower_model.add(MaxPooling2D((2, 2),padding='same'))
flower_model.add(Dropout(0.5))

flower_model.add(Flatten())
flower_model.add(Dense(32, activation='linear'))
flower_model.add(LeakyReLU(alpha=0.1))
flower_model.add(Dropout(0.5))
flower_model.add(Dense(nClasses, activation='softmax'))

# %%
flower_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 32, 32, 16)        1216
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 32, 32, 16)        0
#
#  max_pooling2d_7 (MaxPoolin  (None, 16, 16, 16)        0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 16, 16, 16)        0
#
#  flatten_7 (Flatten)         (None, 4096)              0
#
#  dense_14 (Dense)            (None, 32)                131104
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 32)                0
#
#  dropout_15 (Dropout)        (None, 32)                0
#
#  dense_15 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 132485 (517.52 KB)
# Trainable params: 132485 (517.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
flower_model.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.legacy.SGD(learning_rate=INIT_LR, decay=INIT_LR / 100),metrics=['accuracy'])

# %% [markdown]
# # Entrenamos el modelo: Aprende a clasificar imágenes

# %%
# este paso puede tomar varios minutos, dependiendo de tu ordenador, cpu y memoria ram libre
flower_train = flower_model.fit(train_X, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label))
# Out:
# Epoch 1/200
# 241/241 [==============================] - 2s 8ms/step - loss: 1.4399 - accuracy: 0.3937 - val_loss: 1.2013 - val_accuracy: 0.5322
# Epoch 2/200
# 241/241 [==============================] - 2s 7ms/step - loss: 1.2143 - accuracy: 0.5125 - val_loss: 1.0347 - val_accuracy: 0.6315
# Epoch 3/200
# 241/241 [==============================] - 2s 7ms/step - loss: 1.1013 - accuracy: 0.5565 - val_loss: 0.9443 - val_accuracy: 0.6325
# Epoch 4/200
# 241/241 [==============================] - 2s 7ms/step - loss: 1.0348 - accuracy: 0.5841 - val_loss: 0.8714 - val_accuracy: 0.6502
# Epoch 5/200
# 241/241 [==============================] - 2s 7ms/step - loss: 0.9818 - accuracy: 0.6050 - val_loss: 0.8212 - val_accuracy: 0.6575
# Epoch 6/200
# 241/241 [==============================] - 2s 7ms/step - loss: 0.9284 - accuracy: 0.6242 - val_loss: 0.7661 - val_accuracy: 0.6918
# Epoch 7/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.9011 - accuracy: 0.6422 - val_loss: 0.7205 - val_accuracy: 0.7354
# Epoch 8/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.8506 - accuracy: 0.6703 - val_loss: 0.6775 - val_accuracy: 0.7791
# Epoch 9/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.8216 - accuracy: 0.6810 - val_loss: 0.6418 - val_accuracy: 0.7890
# Epoch 10/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.7934 - accuracy: 0.6988 - val_loss: 0.6135 - val_accuracy: 0.8087
# Epoch 11/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.7517 - accuracy: 0.7062 - val_loss: 0.5796 - val_accuracy: 0.8368
# Epoch 12/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.7119 - accuracy: 0.7300 - val_loss: 0.5537 - val_accuracy: 0.8186
# Epoch 13/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.6889 - accuracy: 0.7442 - val_loss: 0.5236 - val_accuracy: 0.8597
# Epoch 14/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.6758 - accuracy: 0.7501 - val_loss: 0.5007 - val_accuracy: 0.8545
# Epoch 15/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.6538 - accuracy: 0.7577 - val_loss: 0.4848 - val_accuracy: 0.8565
# Epoch 16/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.6302 - accuracy: 0.7713 - val_loss: 0.4627 - val_accuracy: 0.8654
# Epoch 17/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.6116 - accuracy: 0.7772 - val_loss: 0.4488 - val_accuracy: 0.8649
# Epoch 18/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.5895 - accuracy: 0.7879 - val_loss: 0.4392 - val_accuracy: 0.8680
# Epoch 19/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.5792 - accuracy: 0.7902 - val_loss: 0.4243 - val_accuracy: 0.8695
# Epoch 20/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.5595 - accuracy: 0.7999 - val_loss: 0.4079 - val_accuracy: 0.8773
# Epoch 21/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.5507 - accuracy: 0.8068 - val_loss: 0.4011 - val_accuracy: 0.8825
# Epoch 22/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.5499 - accuracy: 0.8018 - val_loss: 0.3923 - val_accuracy: 0.8779
# Epoch 23/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.5320 - accuracy: 0.8111 - val_loss: 0.3809 - val_accuracy: 0.8825
# Epoch 24/200
# 241/241 [==============================] - 3s 11ms/step - loss: 0.5222 - accuracy: 0.8168 - val_loss: 0.3717 - val_accuracy: 0.8903
# Epoch 25/200
# 241/241 [==============================] - 3s 11ms/step - loss: 0.5108 - accuracy: 0.8164 - val_loss: 0.3705 - val_accuracy: 0.8929
# Epoch 26/200
# 241/241 [==============================] - 3s 11ms/step - loss: 0.5027 - accuracy: 0.8248 - val_loss: 0.3606 - val_accuracy: 0.8935
# Epoch 27/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.4950 - accuracy: 0.8256 - val_loss: 0.3534 - val_accuracy: 0.8960
# Epoch 28/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.4851 - accuracy: 0.8333 - val_loss: 0.3427 - val_accuracy: 0.9038
# Epoch 29/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.4796 - accuracy: 0.8368 - val_loss: 0.3382 - val_accuracy: 0.9044
# Epoch 30/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.4754 - accuracy: 0.8364 - val_loss: 0.3343 - val_accuracy: 0.9054
# Epoch 31/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.4644 - accuracy: 0.8450 - val_loss: 0.3258 - val_accuracy: 0.9106
# Epoch 32/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.4617 - accuracy: 0.8389 - val_loss: 0.3218 - val_accuracy: 0.9064
# Epoch 33/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.4550 - accuracy: 0.8445 - val_loss: 0.3146 - val_accuracy: 0.9106
# Epoch 34/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.4400 - accuracy: 0.8473 - val_loss: 0.3156 - val_accuracy: 0.9044
# Epoch 35/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.4411 - accuracy: 0.8503 - val_loss: 0.3082 - val_accuracy: 0.9075
# Epoch 36/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.4342 - accuracy: 0.8507 - val_loss: 0.3017 - val_accuracy: 0.9142
# Epoch 37/200
# 241/241 [==============================] - 6s 25ms/step - loss: 0.4284 - accuracy: 0.8559 - val_loss: 0.2982 - val_accuracy: 0.9158
# Epoch 38/200
# 241/241 [==============================] - 6s 24ms/step - loss: 0.4234 - accuracy: 0.8552 - val_loss: 0.2941 - val_accuracy: 0.9158
# Epoch 39/200
# 241/241 [==============================] - 6s 24ms/step - loss: 0.4157 - accuracy: 0.8619 - val_loss: 0.2904 - val_accuracy: 0.9127
# Epoch 40/200
# 241/241 [==============================] - 6s 23ms/step - loss: 0.4142 - accuracy: 0.8610 - val_loss: 0.2860 - val_accuracy: 0.9220
# Epoch 41/200
# 241/241 [==============================] - 5s 22ms/step - loss: 0.4082 - accuracy: 0.8632 - val_loss: 0.2832 - val_accuracy: 0.9168
# Epoch 42/200
# 241/241 [==============================] - 5s 22ms/step - loss: 0.3920 - accuracy: 0.8745 - val_loss: 0.2816 - val_accuracy: 0.9153
# Epoch 43/200
# 241/241 [==============================] - 5s 19ms/step - loss: 0.4025 - accuracy: 0.8649 - val_loss: 0.2766 - val_accuracy: 0.9174
# Epoch 44/200
# 241/241 [==============================] - 2s 10ms/step - loss: 0.3878 - accuracy: 0.8682 - val_loss: 0.2720 - val_accuracy: 0.9236
# Epoch 45/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.3832 - accuracy: 0.8658 - val_loss: 0.2831 - val_accuracy: 0.9148
# Epoch 46/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.3855 - accuracy: 0.8710 - val_loss: 0.2647 - val_accuracy: 0.9252
# Epoch 47/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.3731 - accuracy: 0.8751 - val_loss: 0.2731 - val_accuracy: 0.9122
# Epoch 48/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3806 - accuracy: 0.8719 - val_loss: 0.2628 - val_accuracy: 0.9246
# Epoch 49/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3684 - accuracy: 0.8777 - val_loss: 0.2550 - val_accuracy: 0.9278
# Epoch 50/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3658 - accuracy: 0.8785 - val_loss: 0.2550 - val_accuracy: 0.9257
# Epoch 51/200
# 241/241 [==============================] - 3s 11ms/step - loss: 0.3758 - accuracy: 0.8753 - val_loss: 0.2585 - val_accuracy: 0.9220
# Epoch 52/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3576 - accuracy: 0.8832 - val_loss: 0.2514 - val_accuracy: 0.9272
# Epoch 53/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.3600 - accuracy: 0.8786 - val_loss: 0.2472 - val_accuracy: 0.9288
# Epoch 54/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3530 - accuracy: 0.8849 - val_loss: 0.2453 - val_accuracy: 0.9288
# Epoch 55/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3527 - accuracy: 0.8821 - val_loss: 0.2418 - val_accuracy: 0.9324
# Epoch 56/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3528 - accuracy: 0.8815 - val_loss: 0.2397 - val_accuracy: 0.9324
# Epoch 57/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3514 - accuracy: 0.8799 - val_loss: 0.2361 - val_accuracy: 0.9319
# Epoch 58/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3433 - accuracy: 0.8859 - val_loss: 0.2378 - val_accuracy: 0.9314
# Epoch 59/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3425 - accuracy: 0.8864 - val_loss: 0.2358 - val_accuracy: 0.9324
# Epoch 60/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.3453 - accuracy: 0.8821 - val_loss: 0.2318 - val_accuracy: 0.9314
# Epoch 61/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3359 - accuracy: 0.8867 - val_loss: 0.2290 - val_accuracy: 0.9335
# Epoch 62/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3278 - accuracy: 0.8902 - val_loss: 0.2240 - val_accuracy: 0.9340
# Epoch 63/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.3228 - accuracy: 0.8919 - val_loss: 0.2329 - val_accuracy: 0.9283
# Epoch 64/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3306 - accuracy: 0.8906 - val_loss: 0.2203 - val_accuracy: 0.9340
# Epoch 65/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3183 - accuracy: 0.8946 - val_loss: 0.2181 - val_accuracy: 0.9309
# Epoch 66/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.3226 - accuracy: 0.8912 - val_loss: 0.2211 - val_accuracy: 0.9288
# Epoch 67/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.3176 - accuracy: 0.8946 - val_loss: 0.2136 - val_accuracy: 0.9371
# Epoch 68/200
# 241/241 [==============================] - 4s 16ms/step - loss: 0.3122 - accuracy: 0.8951 - val_loss: 0.2117 - val_accuracy: 0.9381
# Epoch 69/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.3130 - accuracy: 0.8968 - val_loss: 0.2123 - val_accuracy: 0.9371
# Epoch 70/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3080 - accuracy: 0.8996 - val_loss: 0.2095 - val_accuracy: 0.9345
# Epoch 71/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3075 - accuracy: 0.9046 - val_loss: 0.2068 - val_accuracy: 0.9366
# Epoch 72/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3025 - accuracy: 0.9016 - val_loss: 0.2095 - val_accuracy: 0.9345
# Epoch 73/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.3103 - accuracy: 0.9009 - val_loss: 0.2056 - val_accuracy: 0.9356
# Epoch 74/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3028 - accuracy: 0.8998 - val_loss: 0.2081 - val_accuracy: 0.9350
# Epoch 75/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3046 - accuracy: 0.8999 - val_loss: 0.2060 - val_accuracy: 0.9371
# Epoch 76/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.3067 - accuracy: 0.8944 - val_loss: 0.2109 - val_accuracy: 0.9397
# Epoch 77/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2965 - accuracy: 0.9027 - val_loss: 0.2037 - val_accuracy: 0.9376
# Epoch 78/200
# 241/241 [==============================] - 4s 16ms/step - loss: 0.2989 - accuracy: 0.9038 - val_loss: 0.2023 - val_accuracy: 0.9397
# Epoch 79/200
# 241/241 [==============================] - 4s 17ms/step - loss: 0.3029 - accuracy: 0.9009 - val_loss: 0.1982 - val_accuracy: 0.9361
# Epoch 80/200
# 241/241 [==============================] - 3s 11ms/step - loss: 0.2904 - accuracy: 0.9061 - val_loss: 0.1952 - val_accuracy: 0.9387
# Epoch 81/200
# 241/241 [==============================] - 3s 10ms/step - loss: 0.2896 - accuracy: 0.9016 - val_loss: 0.1934 - val_accuracy: 0.9418
# Epoch 82/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2986 - accuracy: 0.9038 - val_loss: 0.1941 - val_accuracy: 0.9371
# Epoch 83/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2882 - accuracy: 0.9075 - val_loss: 0.1969 - val_accuracy: 0.9371
# Epoch 84/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2856 - accuracy: 0.9057 - val_loss: 0.1898 - val_accuracy: 0.9387
# Epoch 85/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2862 - accuracy: 0.9048 - val_loss: 0.1902 - val_accuracy: 0.9387
# Epoch 86/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2896 - accuracy: 0.9083 - val_loss: 0.1878 - val_accuracy: 0.9433
# Epoch 87/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2803 - accuracy: 0.9076 - val_loss: 0.1876 - val_accuracy: 0.9433
# Epoch 88/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2794 - accuracy: 0.9072 - val_loss: 0.1858 - val_accuracy: 0.9439
# Epoch 89/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2802 - accuracy: 0.9067 - val_loss: 0.1837 - val_accuracy: 0.9381
# Epoch 90/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2723 - accuracy: 0.9084 - val_loss: 0.1824 - val_accuracy: 0.9418
# Epoch 91/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2737 - accuracy: 0.9102 - val_loss: 0.1806 - val_accuracy: 0.9470
# Epoch 92/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2813 - accuracy: 0.9077 - val_loss: 0.1828 - val_accuracy: 0.9444
# Epoch 93/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2772 - accuracy: 0.9083 - val_loss: 0.1826 - val_accuracy: 0.9470
# Epoch 94/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2636 - accuracy: 0.9142 - val_loss: 0.1815 - val_accuracy: 0.9470
# Epoch 95/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2740 - accuracy: 0.9058 - val_loss: 0.1805 - val_accuracy: 0.9485
# Epoch 96/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2675 - accuracy: 0.9128 - val_loss: 0.1770 - val_accuracy: 0.9428
# Epoch 97/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2692 - accuracy: 0.9136 - val_loss: 0.1792 - val_accuracy: 0.9454
# Epoch 98/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2600 - accuracy: 0.9149 - val_loss: 0.1800 - val_accuracy: 0.9470
# Epoch 99/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2652 - accuracy: 0.9115 - val_loss: 0.1770 - val_accuracy: 0.9433
# Epoch 100/200
# 241/241 [==============================] - 2s 10ms/step - loss: 0.2707 - accuracy: 0.9110 - val_loss: 0.1750 - val_accuracy: 0.9470
# Epoch 101/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2590 - accuracy: 0.9142 - val_loss: 0.1737 - val_accuracy: 0.9465
# Epoch 102/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2550 - accuracy: 0.9154 - val_loss: 0.1715 - val_accuracy: 0.9470
# Epoch 103/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2502 - accuracy: 0.9158 - val_loss: 0.1698 - val_accuracy: 0.9501
# Epoch 104/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2592 - accuracy: 0.9183 - val_loss: 0.1700 - val_accuracy: 0.9496
# Epoch 105/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2535 - accuracy: 0.9158 - val_loss: 0.1697 - val_accuracy: 0.9465
# Epoch 106/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2552 - accuracy: 0.9185 - val_loss: 0.1677 - val_accuracy: 0.9475
# Epoch 107/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2530 - accuracy: 0.9197 - val_loss: 0.1708 - val_accuracy: 0.9506
# Epoch 108/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2481 - accuracy: 0.9183 - val_loss: 0.1675 - val_accuracy: 0.9506
# Epoch 109/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2539 - accuracy: 0.9163 - val_loss: 0.1811 - val_accuracy: 0.9485
# Epoch 110/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2602 - accuracy: 0.9167 - val_loss: 0.1652 - val_accuracy: 0.9511
# Epoch 111/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2488 - accuracy: 0.9149 - val_loss: 0.1643 - val_accuracy: 0.9522
# Epoch 112/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2518 - accuracy: 0.9190 - val_loss: 0.1627 - val_accuracy: 0.9532
# Epoch 113/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2523 - accuracy: 0.9185 - val_loss: 0.1678 - val_accuracy: 0.9506
# Epoch 114/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2513 - accuracy: 0.9170 - val_loss: 0.1661 - val_accuracy: 0.9491
# Epoch 115/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2426 - accuracy: 0.9215 - val_loss: 0.1643 - val_accuracy: 0.9522
# Epoch 116/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2419 - accuracy: 0.9205 - val_loss: 0.1604 - val_accuracy: 0.9553
# Epoch 117/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2484 - accuracy: 0.9175 - val_loss: 0.1626 - val_accuracy: 0.9511
# Epoch 118/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2443 - accuracy: 0.9206 - val_loss: 0.1613 - val_accuracy: 0.9527
# Epoch 119/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2473 - accuracy: 0.9167 - val_loss: 0.1615 - val_accuracy: 0.9511
# Epoch 120/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2437 - accuracy: 0.9201 - val_loss: 0.1632 - val_accuracy: 0.9527
# Epoch 121/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2383 - accuracy: 0.9197 - val_loss: 0.1619 - val_accuracy: 0.9527
# Epoch 122/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2340 - accuracy: 0.9240 - val_loss: 0.1568 - val_accuracy: 0.9548
# Epoch 123/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2419 - accuracy: 0.9213 - val_loss: 0.1558 - val_accuracy: 0.9569
# Epoch 124/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2260 - accuracy: 0.9259 - val_loss: 0.1648 - val_accuracy: 0.9480
# Epoch 125/200
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2422 - accuracy: 0.9215 - val_loss: 0.1651 - val_accuracy: 0.9506
# Epoch 126/200
# 241/241 [==============================] - 6s 26ms/step - loss: 0.2344 - accuracy: 0.9232 - val_loss: 0.1586 - val_accuracy: 0.9511
# Epoch 127/200
# 241/241 [==============================] - 6s 24ms/step - loss: 0.2320 - accuracy: 0.9231 - val_loss: 0.1642 - val_accuracy: 0.9517
# Epoch 128/200
# 241/241 [==============================] - 5s 22ms/step - loss: 0.2452 - accuracy: 0.9215 - val_loss: 0.1581 - val_accuracy: 0.9532
# Epoch 129/200
# 241/241 [==============================] - 5s 22ms/step - loss: 0.2316 - accuracy: 0.9235 - val_loss: 0.1568 - val_accuracy: 0.9537
# Epoch 130/200
# 241/241 [==============================] - 6s 24ms/step - loss: 0.2342 - accuracy: 0.9265 - val_loss: 0.1566 - val_accuracy: 0.9522
# Epoch 131/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2295 - accuracy: 0.9261 - val_loss: 0.1593 - val_accuracy: 0.9527
# Epoch 132/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2332 - accuracy: 0.9206 - val_loss: 0.1529 - val_accuracy: 0.9569
# Epoch 133/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2343 - accuracy: 0.9253 - val_loss: 0.1524 - val_accuracy: 0.9563
# Epoch 134/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2276 - accuracy: 0.9211 - val_loss: 0.1512 - val_accuracy: 0.9579
# Epoch 135/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2319 - accuracy: 0.9254 - val_loss: 0.1506 - val_accuracy: 0.9595
# Epoch 136/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2226 - accuracy: 0.9266 - val_loss: 0.1532 - val_accuracy: 0.9548
# Epoch 137/200
# 241/241 [==============================] - 2s 10ms/step - loss: 0.2281 - accuracy: 0.9239 - val_loss: 0.1512 - val_accuracy: 0.9553
# Epoch 138/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2216 - accuracy: 0.9250 - val_loss: 0.1496 - val_accuracy: 0.9579
# Epoch 139/200
# 241/241 [==============================] - 2s 10ms/step - loss: 0.2243 - accuracy: 0.9259 - val_loss: 0.1491 - val_accuracy: 0.9579
# Epoch 140/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2231 - accuracy: 0.9281 - val_loss: 0.1512 - val_accuracy: 0.9532
# Epoch 141/200
# 241/241 [==============================] - 3s 12ms/step - loss: 0.2299 - accuracy: 0.9229 - val_loss: 0.1507 - val_accuracy: 0.9548
# Epoch 142/200
# 241/241 [==============================] - 5s 20ms/step - loss: 0.2249 - accuracy: 0.9285 - val_loss: 0.1472 - val_accuracy: 0.9610
# Epoch 143/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2244 - accuracy: 0.9257 - val_loss: 0.1484 - val_accuracy: 0.9579
# Epoch 144/200
# 241/241 [==============================] - 2s 10ms/step - loss: 0.2237 - accuracy: 0.9275 - val_loss: 0.1466 - val_accuracy: 0.9584
# Epoch 145/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2227 - accuracy: 0.9262 - val_loss: 0.1477 - val_accuracy: 0.9553
# Epoch 146/200
# 241/241 [==============================] - 3s 10ms/step - loss: 0.2139 - accuracy: 0.9272 - val_loss: 0.1453 - val_accuracy: 0.9589
# Epoch 147/200
# 241/241 [==============================] - 3s 11ms/step - loss: 0.2191 - accuracy: 0.9292 - val_loss: 0.1456 - val_accuracy: 0.9584
# Epoch 148/200
# 241/241 [==============================] - 3s 11ms/step - loss: 0.2259 - accuracy: 0.9257 - val_loss: 0.1469 - val_accuracy: 0.9543
# Epoch 149/200
# 241/241 [==============================] - 3s 11ms/step - loss: 0.2134 - accuracy: 0.9279 - val_loss: 0.1456 - val_accuracy: 0.9569
# Epoch 150/200
# 241/241 [==============================] - 3s 12ms/step - loss: 0.2235 - accuracy: 0.9268 - val_loss: 0.1457 - val_accuracy: 0.9574
# Epoch 151/200
# 241/241 [==============================] - 3s 11ms/step - loss: 0.2173 - accuracy: 0.9267 - val_loss: 0.1452 - val_accuracy: 0.9558
# Epoch 152/200
# 241/241 [==============================] - 3s 13ms/step - loss: 0.2198 - accuracy: 0.9270 - val_loss: 0.1462 - val_accuracy: 0.9563
# Epoch 153/200
# 241/241 [==============================] - 7s 31ms/step - loss: 0.2148 - accuracy: 0.9314 - val_loss: 0.1434 - val_accuracy: 0.9600
# Epoch 154/200
# 241/241 [==============================] - 7s 31ms/step - loss: 0.2192 - accuracy: 0.9272 - val_loss: 0.1427 - val_accuracy: 0.9584
# Epoch 155/200
# 241/241 [==============================] - 7s 30ms/step - loss: 0.2164 - accuracy: 0.9276 - val_loss: 0.1423 - val_accuracy: 0.9584
# Epoch 156/200
# 241/241 [==============================] - 8s 32ms/step - loss: 0.2160 - accuracy: 0.9313 - val_loss: 0.1429 - val_accuracy: 0.9579
# Epoch 157/200
# 241/241 [==============================] - 7s 30ms/step - loss: 0.2115 - accuracy: 0.9280 - val_loss: 0.1410 - val_accuracy: 0.9600
# Epoch 158/200
# 241/241 [==============================] - 6s 23ms/step - loss: 0.2130 - accuracy: 0.9278 - val_loss: 0.1465 - val_accuracy: 0.9553
# Epoch 159/200
# 241/241 [==============================] - 2s 10ms/step - loss: 0.2119 - accuracy: 0.9297 - val_loss: 0.1420 - val_accuracy: 0.9569
# Epoch 160/200
# 241/241 [==============================] - 3s 11ms/step - loss: 0.2152 - accuracy: 0.9318 - val_loss: 0.1389 - val_accuracy: 0.9621
# Epoch 161/200
# 241/241 [==============================] - 2s 10ms/step - loss: 0.2116 - accuracy: 0.9309 - val_loss: 0.1417 - val_accuracy: 0.9563
# Epoch 162/200
# 241/241 [==============================] - 2s 10ms/step - loss: 0.2081 - accuracy: 0.9311 - val_loss: 0.1423 - val_accuracy: 0.9537
# Epoch 163/200
# 241/241 [==============================] - 2s 10ms/step - loss: 0.2109 - accuracy: 0.9328 - val_loss: 0.1380 - val_accuracy: 0.9621
# Epoch 164/200
# 241/241 [==============================] - 2s 10ms/step - loss: 0.2134 - accuracy: 0.9350 - val_loss: 0.1382 - val_accuracy: 0.9605
# Epoch 165/200
# 241/241 [==============================] - 2s 10ms/step - loss: 0.2043 - accuracy: 0.9297 - val_loss: 0.1407 - val_accuracy: 0.9579
# Epoch 166/200
# 241/241 [==============================] - 2s 10ms/step - loss: 0.2075 - accuracy: 0.9326 - val_loss: 0.1433 - val_accuracy: 0.9553
# Epoch 167/200
# 241/241 [==============================] - 3s 10ms/step - loss: 0.2073 - accuracy: 0.9337 - val_loss: 0.1372 - val_accuracy: 0.9615
# Epoch 168/200
# 241/241 [==============================] - 2s 10ms/step - loss: 0.2042 - accuracy: 0.9327 - val_loss: 0.1363 - val_accuracy: 0.9626
# Epoch 169/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2138 - accuracy: 0.9280 - val_loss: 0.1392 - val_accuracy: 0.9569
# Epoch 170/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2063 - accuracy: 0.9324 - val_loss: 0.1356 - val_accuracy: 0.9626
# Epoch 171/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2129 - accuracy: 0.9315 - val_loss: 0.1395 - val_accuracy: 0.9579
# Epoch 172/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2077 - accuracy: 0.9317 - val_loss: 0.1357 - val_accuracy: 0.9610
# Epoch 173/200
# 241/241 [==============================] - 4s 17ms/step - loss: 0.2023 - accuracy: 0.9330 - val_loss: 0.1411 - val_accuracy: 0.9553
# Epoch 174/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2039 - accuracy: 0.9331 - val_loss: 0.1360 - val_accuracy: 0.9610
# Epoch 175/200
# 241/241 [==============================] - 2s 10ms/step - loss: 0.2075 - accuracy: 0.9309 - val_loss: 0.1342 - val_accuracy: 0.9621
# Epoch 176/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.1953 - accuracy: 0.9341 - val_loss: 0.1350 - val_accuracy: 0.9605
# Epoch 177/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2026 - accuracy: 0.9310 - val_loss: 0.1355 - val_accuracy: 0.9600
# Epoch 178/200
# 241/241 [==============================] - 2s 10ms/step - loss: 0.2003 - accuracy: 0.9335 - val_loss: 0.1362 - val_accuracy: 0.9589
# Epoch 179/200
# 241/241 [==============================] - 3s 11ms/step - loss: 0.2029 - accuracy: 0.9339 - val_loss: 0.1339 - val_accuracy: 0.9610
# Epoch 180/200
# 241/241 [==============================] - 3s 11ms/step - loss: 0.1995 - accuracy: 0.9344 - val_loss: 0.1341 - val_accuracy: 0.9600
# Epoch 181/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.1974 - accuracy: 0.9336 - val_loss: 0.1342 - val_accuracy: 0.9610
# Epoch 182/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2036 - accuracy: 0.9345 - val_loss: 0.1419 - val_accuracy: 0.9574
# Epoch 183/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.1977 - accuracy: 0.9333 - val_loss: 0.1320 - val_accuracy: 0.9647
# Epoch 184/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2021 - accuracy: 0.9330 - val_loss: 0.1309 - val_accuracy: 0.9647
# Epoch 185/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2040 - accuracy: 0.9319 - val_loss: 0.1323 - val_accuracy: 0.9610
# Epoch 186/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2003 - accuracy: 0.9324 - val_loss: 0.1366 - val_accuracy: 0.9569
# Epoch 187/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2027 - accuracy: 0.9315 - val_loss: 0.1442 - val_accuracy: 0.9548
# Epoch 188/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.1977 - accuracy: 0.9331 - val_loss: 0.1322 - val_accuracy: 0.9595
# Epoch 189/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.1960 - accuracy: 0.9378 - val_loss: 0.1347 - val_accuracy: 0.9589
# Epoch 190/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.1957 - accuracy: 0.9354 - val_loss: 0.1301 - val_accuracy: 0.9631
# Epoch 191/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.1999 - accuracy: 0.9345 - val_loss: 0.1316 - val_accuracy: 0.9595
# Epoch 192/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.2016 - accuracy: 0.9340 - val_loss: 0.1308 - val_accuracy: 0.9615
# Epoch 193/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.1971 - accuracy: 0.9343 - val_loss: 0.1315 - val_accuracy: 0.9631
# Epoch 194/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.1901 - accuracy: 0.9341 - val_loss: 0.1294 - val_accuracy: 0.9610
# Epoch 195/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.1984 - accuracy: 0.9358 - val_loss: 0.1281 - val_accuracy: 0.9641
# Epoch 196/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.2008 - accuracy: 0.9349 - val_loss: 0.1325 - val_accuracy: 0.9589
# Epoch 197/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.1978 - accuracy: 0.9336 - val_loss: 0.1316 - val_accuracy: 0.9595
# Epoch 198/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.1940 - accuracy: 0.9370 - val_loss: 0.1289 - val_accuracy: 0.9626
# Epoch 199/200
# 241/241 [==============================] - 2s 9ms/step - loss: 0.1962 - accuracy: 0.9332 - val_loss: 0.1275 - val_accuracy: 0.9631
# Epoch 200/200
# 241/241 [==============================] - 2s 8ms/step - loss: 0.1949 - accuracy: 0.9352 - val_loss: 0.1271 - val_accuracy: 0.9647

# %%
# guardamos la red, para reutilizarla en el futuro, sin tener que volver a entrenar
flower_model.save("./flores.h5py")
# Out:
# INFO:tensorflow:Assets written to: ./flores.h5py\assets
# INFO:tensorflow:Assets written to: ./flores.h5py\assets

# %% [markdown]
# # Evaluamos la red

# %%
test_eval = flower_model.evaluate(test_X, test_Y_one_hot, verbose=1)
# Out:
# 76/76 [==============================] - 0s 3ms/step - loss: 0.1291 - accuracy: 0.9680

# %%
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# Test loss: 0.1291269063949585
# Test accuracy: 0.9679833650588989

# %%
flower_model.history

# %%
accuracy = flower_train.history['accuracy']
val_accuracy = flower_train.history['val_accuracy']
loss = flower_train.history['loss']
val_loss = flower_train.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
predicted_classes2 = flower_model.predict(test_X)
# Out:
# 76/76 [==============================] - 0s 4ms/step

# %%
predicted_classes=[]
for predicted_flower in predicted_classes2:
    predicted_classes.append(predicted_flower.tolist().index(max(predicted_flower)))
predicted_classes=np.array(predicted_classes)

# %%
predicted_classes.shape, test_Y.shape
# Out:
# ((2405,), (2405,))

# %% [markdown]
# # Aprendamos de los errores: Qué mejorar

# %%
correct = np.where(predicted_classes==test_Y)[0]
print("Found %d correct labels" % len(correct))
for i, correct in enumerate(correct[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[correct].reshape(32,32,3), cmap='gray', interpolation='none')
    plt.title("{}, {}".format(flores[predicted_classes[correct]],
                                                    flores[test_Y[correct]]))

    plt.tight_layout()
# Out:
# Found 2328 correct labels

# %%
incorrect = np.where(predicted_classes!=test_Y)[0]
print("Found %d incorrect labels" % len(incorrect))
for i, incorrect in enumerate(incorrect[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[incorrect].reshape(32,32,3), cmap='gray', interpolation='none')
    plt.title("{}, {}".format(flores[predicted_classes[incorrect]],
                                                    flores[test_Y[incorrect]]))
    plt.tight_layout()
# Out:
# Found 77 incorrect labels

# %%
target_names = ["Class {}".format(i) for i in range(nClasses)]
print(classification_report(test_Y, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.95      0.97      0.96       728
#      Class 1       0.97      0.94      0.95       663
#      Class 2       0.99      0.99      0.99       327
#      Class 3       0.97      0.98      0.98       403
#      Class 4       1.00      0.97      0.98       284
#
#     accuracy                           0.97      2405
#    macro avg       0.97      0.97      0.97      2405
# weighted avg       0.97      0.97      0.97      2405
